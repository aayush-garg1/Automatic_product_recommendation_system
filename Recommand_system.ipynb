# %%
# !pip install tensorflow-recommenders
# Out:
# Requirement already satisfied: tensorflow-recommenders in c:\users\administrator\anaconda3\lib\site-packages (0.7.3)
# Requirement already satisfied: absl-py>=0.1.6 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-recommenders) (2.1.0)
# Requirement already satisfied: tensorflow>=2.9.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-recommenders) (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow>=2.9.0->tensorflow-recommenders) (2.15.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (3.3.0)
# Requirement already satisfied: packaging in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (1.62.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\administrator\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\administrator\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\administrator\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\administrator\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\administrator\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\administrator\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\administrator\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\administrator\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\administrator\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\administrator\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrator\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrator\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrator\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrator\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\administrator\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\administrator\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\administrator\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=2.9.0->tensorflow-recommenders) (3.2.2)

# %%
# !pip install scann
# Out:
# ERROR: Could not find a version that satisfies the requirement scann (from versions: none)
# ERROR: No matching distribution found for scann

# %%
import os
import pprint
import tempfile 
import pandas as pd
from typing import Dict, Text
import numpy as np
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\Administrator\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_csv('amazon_product_beer.csv')
df
# Out:
#       brewery_id  score        username                                  text  \
# 0          10325    1.5         stcules                My Favorite White Wine
# 1          10325    3.0         stcules                                 Yum!!
# 2          10325    3.0         stcules                       A New Favorite!
# 3          10325    3.0         stcules  Bold, Flavorful, Aromatic, Delicious
# 4           1075    4.0  johnmichaelsen  Yum! Plus, Environmentally Friendly!
# ...          ...    ...             ...                                   ...
# 2841       14879    4.0      goblue3509                             Excellent
# 2842       14879    4.0          heysuz                          Delicious !!
# 2843       14879    4.0      BeerWanker             Sumptuous delicious wine.
# 2844       14879    1.5    PittBeerGirl                     Excellent Moscato
# 2845       14879    4.0        Beaver13   O'Leary's Select Reserve Chardonnay
#
#                                style   abv             brewery_name  \
# 0                         Hefeweizen   5.0          Vecchio Birraio
# 1                 English Strong Ale   6.2          Vecchio Birraio
# 2             Foreign / Export Stout   6.5          Vecchio Birraio
# 3                    German Pilsener   5.0          Vecchio Birraio
# 4     American Double / Imperial IPA   7.7  Caldera Brewing Company
# ...                              ...   ...                      ...
# 2841  American Double / Imperial IPA  10.0     Hoppin' Frog Brewery
# 2842  American Double / Imperial IPA  10.0     Hoppin' Frog Brewery
# 2843  American Double / Imperial IPA  10.0     Hoppin' Frog Brewery
# 2844  American Double / Imperial IPA  10.0     Hoppin' Frog Brewery
# 2845  American Double / Imperial IPA  10.0     Hoppin' Frog Brewery
#
#                    beer_name
# 0               Sausa Weizen
# 1                   Red Moon
# 2     Black Horse Black Beer
# 3                 Sausa Pils
# 4              Cauldron DIPA
# ...                      ...
# 2841      Hop Dam Triple IPA
# 2842      Hop Dam Triple IPA
# 2843      Hop Dam Triple IPA
# 2844      Hop Dam Triple IPA
# 2845      Hop Dam Triple IPA
#
# [2846 rows x 8 columns]

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\administrator\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\administrator\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\administrator\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\administrator\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\administrator\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
import matplotlib.pyplot as plt

# %%
word_string1 = " ".join(df['beer_name'].str.lower())
plt.figure(figsize=(15,15))
wc = WordCloud(background_color='white', stopwords=STOPWORDS, max_words=2000, max_font_size=300, width=1600,height=800)
wc.generate(word_string1)

plt.imshow(wc.recolor(colormap='viridis', random_state=17), interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
print("User A reviews")
df[df['username']=='stcules'].head()
# Out:
# User A reviews
#       brewery_id  score username  \
# 0          10325    1.5  stcules
# 1          10325    3.0  stcules
# 2          10325    3.0  stcules
# 3          10325    3.0  stcules
# 1508       16604    4.0  stcules
#
#                                                    text  \
# 0                                My Favorite White Wine
# 1                                                 Yum!!
# 2                                       A New Favorite!
# 3                  Bold, Flavorful, Aromatic, Delicious
# 1508  Perfect for thieving beer from unsuspecting fe...
#
#                        style  abv         brewery_name  \
# 0                 Hefeweizen  5.0      Vecchio Birraio
# 1         English Strong Ale  6.2      Vecchio Birraio
# 2     Foreign / Export Stout  6.5      Vecchio Birraio
# 3            German Pilsener  5.0      Vecchio Birraio
# 1508     Munich Dunkel Lager  NaN  Landhausbräu Koller
#
#                      beer_name
# 0                 Sausa Weizen
# 1                     Red Moon
# 2       Black Horse Black Beer
# 3                   Sausa Pils
# 1508  Kollers Naturtrüb Dunkel

# %%
df_beer = df['beer_name'].unique()
df_beer = pd.DataFrame(df_beer, columns = ['beer_name'])

df_ratings = df[['username', 'beer_name']]
df_ratings = df_ratings.dropna()
tf_beer_dict = tf.data.Dataset.from_tensor_slices(dict(df_beer))
tf_ratings_dict = tf.data.Dataset.from_tensor_slices(dict(df_ratings))

# %%
df_ratings
# Out:
#             username               beer_name
# 0            stcules            Sausa Weizen
# 1            stcules                Red Moon
# 2            stcules  Black Horse Black Beer
# 3            stcules              Sausa Pils
# 4     johnmichaelsen           Cauldron DIPA
# ...              ...                     ...
# 2841      goblue3509      Hop Dam Triple IPA
# 2842          heysuz      Hop Dam Triple IPA
# 2843      BeerWanker      Hop Dam Triple IPA
# 2844    PittBeerGirl      Hop Dam Triple IPA
# 2845        Beaver13      Hop Dam Triple IPA
#
# [2846 rows x 2 columns]

# %%
ratings = tf_ratings_dict.map(lambda x:{"beer_name":x["beer_name"],
                                        "username":x["username"]
                                       })
beer_list = tf_beer_dict.map(lambda x:x["beer_name"])

# %%
usernames = ratings.map(lambda x:x['username'])

# %%
unique_users = np.unique(np.concatenate(list(usernames.batch(1000))))
unique_beers = np.unique(np.concatenate(list(beer_list.batch(1000))))

# %%
tf.random.set_seed(42)
shuffled = ratings.shuffle(len(df), reshuffle_each_iteration=False)

train = shuffled.take(int(len(df)*0.8))
test = shuffled.skip(int(len(df)*0.8)).take(int(len(df)*0.2))

# %%
# %load_ext tensorboard

# %%
import tensorflow_recommenders as tfrs

# %%
class AmazonProduct(tfrs.Model):
    def __init__(self):
        super().__init__()
        
        embeding_dims = 32
        
        self.user_model = tf.keras.Sequential([
            tf.keras.layers.StringLookup(
                vocabulary=unique_users, mask_token=None),
            tf.keras.layers.Embedding(len(unique_users)+1, embeding_dims)
        ])
        
        
        
        self.beer_model = tf.keras.Sequential([
            tf.keras.layers.StringLookup(
                vocabulary=unique_beers, mask_token=None),
            tf.keras.layers.Embedding(len(unique_beers)+1,embeding_dims)
        ])
        
        self.task = tfrs.tasks.Retrieval(
                                metrics=tfrs.metrics.FactorizedTopK(
                                candidates=beer_list.batch(128).cache().map(self.beer_model)))
            
    def compute_loss(self, features: Dict[Text, tf.Tensor], training=False) -> tf.Tensor:
        user_embeding = self.user_model(features['username'])
        beer_embeding = self.beer_model(features['beer_name'])
        return self.task(user_embeding, beer_embeding)

# %%
import datetime
import keras

# %%
logdir = "logs/fit/"+datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

# %%
model = AmazonProduct()
model.compile(optimizer=tf.keras.optimizers.Adagrad(0.5))
# Out:
# WARNING:tensorflow:From C:\Users\Administrator\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Administrator\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.

# %%
freq = 2
epochs = 20

history = model.fit(
                    train.batch(8192),
                    validation_data=test.batch(512),
                    validation_freq=freq,
                    epochs = epochs,
                    verbose = 0,
                    callbacks=[tensorboard_callback])

# %%
# %tensorboard --logdir logs/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 436), started 1 day, 13:51:58 ago. (Use '!kill 436' to kill it.)
#       <iframe id="tensorboard-frame-aff9001536103a2d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-aff9001536103a2d");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model.evaluate(test.batch(8192), return_dict=True)
# Out:
# 1/1 [==============================] - 0s 120ms/step - factorized_top_k/top_1_categorical_accuracy: 0.0018 - factorized_top_k/top_5_categorical_accuracy: 0.0264 - factorized_top_k/top_10_categorical_accuracy: 0.0633 - factorized_top_k/top_50_categorical_accuracy: 0.2882 - factorized_top_k/top_100_categorical_accuracy: 0.4534 - loss: 4625.5454 - regularization_loss: 0.0000e+00 - total_loss: 4625.5454
# {'factorized_top_k/top_1_categorical_accuracy': 0.0017574692610651255,
#  'factorized_top_k/top_5_categorical_accuracy': 0.026362039148807526,
#  'factorized_top_k/top_10_categorical_accuracy': 0.06326889246702194,
#  'factorized_top_k/top_50_categorical_accuracy': 0.2882249653339386,
#  'factorized_top_k/top_100_categorical_accuracy': 0.4534270763397217,
#  'loss': 4625.54541015625,
#  'regularization_loss': 0,
#  'total_loss': 4625.54541015625}

# %%
plt.figure(figsize=(12,6))
num_validation_runs = len(history.history["val_factorized_top_k/top_10_categorical_accuracy"])
epochs = [(x + 1)* freq for x in range(num_validation_runs)]

plt.plot(epochs, history.history["val_factorized_top_k/top_100_categorical_accuracy"], label = "Validation Top 100")
plt.plot(np.linspace(1, len( history.history["factorized_top_k/top_100_categorical_accuracy"]), 
                     len( history.history["factorized_top_k/top_100_categorical_accuracy"])),
                     history.history["factorized_top_k/top_100_categorical_accuracy"], label = "Training Top 100")
plt.plot(epochs, history.history["val_factorized_top_k/top_10_categorical_accuracy"], label = "Validation Top 10")
plt.plot(np.linspace(1, len( history.history["factorized_top_k/top_10_categorical_accuracy"]), 
                     len( history.history["factorized_top_k/top_10_categorical_accuracy"])),
                     history.history["factorized_top_k/top_10_categorical_accuracy"], label = "Training Top 10")
plt.title("Top-100 vs Top-10 Recommendations")
plt.xlabel("epoch")
plt.ylabel("accuracy")
plt.legend()
plt.show()

# %%
index = tfrs.layers.factorized_top_k.BruteForce(model.user_model)
index.index_from_dataset(beer_list.batch(128).map(lambda beer_name: (beer_name, model.beer_model(beer_name))))

# %%
_,titles= index(tf.constant(["stcules"]))

print(f"Recommendations for user stcules: {titles[0, :10]}")
# Out:
# Recommendations for user stcules: [b'Black Horse Black Beer' b'Kollers Naturtr\xc3\xbcb Dunkel'
#  b'Kollers Naturtr\xc3\xbcb Hell' b'Sausa Weizen' b'Red Moon'
#  b'Bernard Nefiltrovan\xc3\xbd (unfiltered)' b'Black Cuillin'
#  b'City Stout' b'City Pumpkin' b'City Razz']
